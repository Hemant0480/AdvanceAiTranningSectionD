# %% [markdown]
# <a href="https://colab.research.google.com/github/Hemant0480/AdvanceAiTranningSectionD/blob/main/speechtotext.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# model

# %%
from torch.nn.modules import padding
from tokenizers import Tokenizer
#create langauge translation python application using transformers
from transformers  import MarianMTModel , MarianTokenizer
#select the model
# model_name = "Helsinki-NLP/opus-mt-en-hi"
#load the model
model = MarianMTModel.from_pretrained("Helsinki-NLP/opus-mt-en-hi")
#load the tokenizer using model name
tokenizer = MarianTokenizer.from_pretrained("Helsinki-NLP/opus-mt-en-hi")
#get the input from user in text
prompt = input("Enter the message to translate")
#encode the text  input  into tokens
input_tokens = tokenizer(prompt, return_tensors="pt",padding=True)
#genrte  the output token s using model
output_tokens = model.generate(**input_tokens)
#decode  the token  into final text
print(tokenizer.decode(output_tokens[0] , skip_special_tokens=True))
# Out:
# Loading weights:   0%|          | 0/258 [00:00<?, ?it/s]
# The tied weights mapping and config for this model specifies to tie model.shared.weight to model.decoder.embed_tokens.weight, but both are present in the checkpoints, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning
# The tied weights mapping and config for this model specifies to tie model.shared.weight to model.encoder.embed_tokens.weight, but both are present in the checkpoints, so we will NOT tie them. You should update the config with `tie_word_embeddings=False` to silence this warning
# Enter the message to translatehello friends
# हैलो दोस्तों को

# %% [markdown]
# upload  the project from google colab to github
# create speech to text application

# %%
#create  voice to text using wishper model and upload decode to gitHub repo
